# %%
from collections import defaultdict
history = defaultdict(list)

# %%
roberta_best_roc_auc = {'train_acc': [0.694, 0.741, 0.76, 0.774, 0.785, 0.796],
 'train_loss': [0.089, 0.0184, 0.0534, 0.023, 0.0295, 0.018],
 'train_precision_score_micro': [0.766,
  0.804,
  0.822,
  0.836,
  0.846,
  0.859],
 'train_precision_score_macro': [0.563,
  0.611,
  0.638,
  0.662,
  0.683,
  0.707],
 'train_recall_score_micro': [0.731,
  0.799,
  0.816,
  0.827,
  0.836,
  0.843],
 'train_recall_score_macro': [0.806,
  0.878,
  0.897,
  0.91,
  0.918,
  0.925],
 'train_f1_score_micro': [0.748,
  0.801,
  0.819,
  0.831,
  0.841,
  0.851],
 'train_f1_score_macro': [0.627,
  0.692,
  0.721,
  0.745,
  0.765,
  0.786],
 'train_rocauc_score_micro': [0.845,
  0.882,
  0.892,
  0.899,
  0.904,
  0.909],
 'train_rocauc_score_macro': [0.881,
  0.92,
  0.931,
  0.939,
  0.944,
  0.948],
 'val_acc': [0.751, 0.764, 0.772, 0.77, 0.794, 0.785],
 'val_loss': [0.061, 0.04, 0.0353, 0.0217, 0.0158, 0.0304],
 'val_precision_score_micro': [0.751,
  0.769,
  0.781,
  0.804,
  0.839,
  0.833],
 'val_precision_score_macro': [0.542,
  0.585,
  0.583,
  0.606,
  0.671,
  0.66],
 'val_recall_score_micro': [0.908,
  0.912,
  0.898,
  0.861,
  0.847,
  0.841],
 'val_recall_score_macro': [0.943,
  0.924,
  0.934,
  0.91,
  0.859,
  0.862],
 'val_f1_score_micro': [0.822, 0.834, 0.836, 0.832, 0.843, 0.837],
 'val_f1_score_macro': [0.658, 0.697, 0.695, 0.703, 0.742, 0.734],
 'val_rocauc_score_micro': [0.927,
  0.931,
  0.927,
  0.912,
  0.909,
  0.905],
 'val_rocauc_score_macro': [0.941,
  0.934,
  0.941,
  0.934,
  0.913,
  0.913]}

# %%
roberta_best_roc_auc
# Out:
# {'train_acc': [0.694, 0.741, 0.76, 0.774, 0.785, 0.796],
#  'train_loss': [0.089, 0.0184, 0.0534, 0.023, 0.0295, 0.018],
#  'train_precision_score_micro': [0.766, 0.804, 0.822, 0.836, 0.846, 0.859],
#  'train_precision_score_macro': [0.563, 0.611, 0.638, 0.662, 0.683, 0.707],
#  'train_recall_score_micro': [0.731, 0.799, 0.816, 0.827, 0.836, 0.843],
#  'train_recall_score_macro': [0.806, 0.878, 0.897, 0.91, 0.918, 0.925],
#  'train_f1_score_micro': [0.748, 0.801, 0.819, 0.831, 0.841, 0.851],
#  'train_f1_score_macro': [0.627, 0.692, 0.721, 0.745, 0.765, 0.786],
#  'train_rocauc_score_micro': [0.845, 0.882, 0.892, 0.899, 0.904, 0.909],
#  'train_rocauc_score_macro': [0.881, 0.92, 0.931, 0.939, 0.944, 0.948],
#  'val_acc': [0.751, 0.764, 0.772, 0.77, 0.794, 0.785],
#  'val_loss': [0.061, 0.04, 0.0353, 0.0217, 0.0158, 0.0304],
#  'val_precision_score_micro': [0.751, 0.769, 0.781, 0.804, 0.839, 0.833],
#  'val_precision_score_macro': [0.542, 0.585, 0.583, 0.606, 0.671, 0.66],
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(roberta_best_roc_auc['train_rocauc_score_macro'], label='train auc_roc')
plt.plot(roberta_best_roc_auc['val_rocauc_score_macro'], label='validation auc_roc')
plt.title('Train vs validation AUC_ROC')
plt.ylabel('auc_roc score')
plt.xlabel('Epoch')
plt.legend()
plt.ylim([0, 1]);
#plt.show()


plt.subplot(1, 2, 2)
plt.plot(roberta_best_roc_auc['train_loss'], label='training loss')
plt.plot(roberta_best_roc_auc['val_loss'], label='validation loss')
plt.title('Train vs validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.ylim([0, 1]);
plt.tight_layout()
plt.show()

# %%
roberta_best_recall = {'train_acc': [0.508, 0.604, 0.641, 0.667, 0.687],
             'train_loss': [0.0316, 0.026, 0.0176, 0.0221, 0.0023],
             'train_precision_score_micro': [0.503,
              0.577,
              0.606,
              0.628,
              0.646],
             'train_precision_score_macro': [0.348,
              0.432,
              0.461,
              0.487,
              0.509],
             'train_recall_score_micro': [0.987, 0.993, 0.995, 0.996, 0.997],
             'train_recall_score_macro': [0.947, 0.975, 0.983, 0.985, 0.989],
             'train_f1_score_micro': [0.666, 0.73, 0.753, 0.771, 0.784],
             'train_f1_score_macro': [0.491, 0.586, 0.616, 0.641, 0.663],
             'train_rocauc_score_micro': [0.905, 0.93, 0.939, 0.944, 0.949],
             'train_rocauc_score_macro': [0.864, 0.904, 0.917, 0.925, 0.932],
             'val_acc': [0.551, 0.54, 0.622, 0.665, 0.678],
             'val_loss': [0.0178, 0.0458, 0.0317, 0.0172, 0.0273],
             'val_precision_score_micro': [0.527, 0.523, 0.582, 0.617, 0.634],
             'val_precision_score_macro': [0.363, 0.394, 0.442, 0.473, 0.498],
             'val_recall_score_micro': [0.996, 0.998, 0.995, 0.991, 0.989],
             'val_recall_score_macro': [0.991, 0.99, 0.981, 0.976, 0.963],
             'val_f1_score_micro': [0.69, 0.687, 0.734, 0.76, 0.772],
             'val_f1_score_macro': [0.507, 0.551, 0.597, 0.625, 0.648],
             'val_rocauc_score_micro': [0.918, 0.917, 0.933, 0.94, 0.943],
             'val_rocauc_score_macro': [0.899, 0.89, 0.909, 0.918, 0.916]}

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(roberta_best_recall['train_recall_score_macro'], label='train recall')
plt.plot(roberta_best_recall['val_recall_score_macro'], label='validation recall')
plt.title('Train vs validation Recall')
plt.ylabel('Recall score')
plt.xlabel('Epoch')
plt.legend()
plt.ylim([0, 1]);
#plt.show()


plt.subplot(1, 2, 2)
plt.plot(roberta_best_recall['train_loss'], label='training loss')
plt.plot(roberta_best_recall['val_loss'], label='validation loss')
plt.title('Train vs validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.ylim([0, 1]);
plt.tight_layout()
plt.show()

# %%
distilbert_best_precision = {'train_acc': [0.737, 0.798, 0.813, 0.825, 0.834],
             'train_loss': [0.2185, 0.1947, 0.118, 0.1098, 0.2139],
             'train_precision_score_micro': [0.819, 0.85, 0.859, 0.869, 0.876],
             'train_precision_score_macro': [0.736,
              0.783,
              0.816,
              0.849,
              0.878],
             'train_recall_score_micro': [0.773, 0.853, 0.872, 0.884, 0.894],
             'train_recall_score_macro': [0.61, 0.737, 0.797, 0.847, 0.881],
             'train_f1_score_micro': [0.795, 0.852, 0.865, 0.876, 0.885],
             'train_f1_score_macro': [0.663, 0.759, 0.806, 0.848, 0.879],
             'train_rocauc_score_micro': [0.871, 0.913, 0.923, 0.93, 0.935],
             'train_rocauc_score_macro': [0.784, 0.85, 0.881, 0.907, 0.925],
             'val_acc': [0.796, 0.807, 0.808, 0.812, 0.806],
             'val_loss': [0.0626, 0.0897, 0.0124, 0.2323, 0.1692],
             'val_precision_score_micro': [0.813, 0.832, 0.843, 0.848, 0.841],
             'val_precision_score_macro': [0.745, 0.745, 0.727, 0.767, 0.747],
             'val_recall_score_micro': [0.891, 0.886, 0.877, 0.871, 0.875],
             'val_recall_score_macro': [0.733, 0.77, 0.78, 0.729, 0.729],
             'val_f1_score_micro': [0.85, 0.858, 0.859, 0.859, 0.858],
             'val_f1_score_macro': [0.735, 0.757, 0.751, 0.745, 0.737],
             'val_rocauc_score_micro': [0.927, 0.927, 0.924, 0.921, 0.923],
             'val_rocauc_score_macro': [0.841, 0.864, 0.871, 0.846, 0.845]}

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(distilbert_best_precision['train_precision_score_macro'], label='train precision')
plt.plot(distilbert_best_precision['val_precision_score_macro'], label='validation precision')
plt.title('Train vs validation Precision')
plt.ylabel('Precision score')
plt.xlabel('Epoch')
plt.legend()
plt.ylim([0, 1]);
#plt.show()


plt.subplot(1, 2, 2)
plt.plot(roberta_best_recall['train_loss'], label='training loss')
plt.plot(roberta_best_recall['val_loss'], label='validation loss')
plt.title('Train vs validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.ylim([0, 1]);
plt.tight_layout()
plt.show()

# %%
bert_best_f1 = {'train_acc': [0.782, 0.827, 0.855, 0.883, 0.906],
             'train_loss': [0.0854, 0.1014, 0.0634, 0.0681, 0.024],
             'train_precision_score_micro': [0.844,
              0.867,
              0.889,
              0.913,
              0.933],
             'train_precision_score_macro': [0.746,
              0.791,
              0.826,
              0.862,
              0.892],
             'train_recall_score_micro': [0.827, 0.889, 0.916, 0.937, 0.951],
             'train_recall_score_macro': [0.618, 0.758, 0.816, 0.864, 0.895],
             'train_f1_score_micro': [0.836, 0.878, 0.902, 0.925, 0.942],
             'train_f1_score_macro': [0.669, 0.773, 0.821, 0.863, 0.894],
             'train_rocauc_score_micro': [0.9, 0.932, 0.948, 0.96, 0.97],
             'train_rocauc_score_macro': [0.79, 0.862, 0.895, 0.921, 0.94],
             'val_acc': [0.809, 0.809, 0.815, 0.813, 0.808],
             'val_loss': [0.0593, 0.1038, 0.0366, 0.079, 0.0748],
             'val_precision_score_micro': [0.824, 0.824, 0.824, 0.842, 0.828],
             'val_precision_score_macro': [0.71, 0.7, 0.721, 0.739, 0.735],
             'val_recall_score_micro': [0.904, 0.908, 0.91, 0.878, 0.897],
             'val_recall_score_macro': [0.806, 0.835, 0.806, 0.776, 0.777],
             'val_f1_score_micro': [0.862, 0.864, 0.865, 0.86, 0.861],
             'val_f1_score_macro': [0.753, 0.759, 0.76, 0.754, 0.755],
             'val_rocauc_score_micro': [0.935, 0.936, 0.938, 0.924, 0.932],
             'val_rocauc_score_macro': [0.88, 0.895, 0.88, 0.868, 0.866]}

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(bert_best_f1['train_f1_score_macro'], label='train f1')
plt.plot(bert_best_f1['val_f1_score_macro'], label='validation f1')
plt.title('Train vs validation F1 score')
plt.ylabel('F1 score')
plt.xlabel('Epoch')
plt.legend()
plt.ylim([0, 1]);
#plt.show()


plt.subplot(1, 2, 2)
plt.plot(bert_best_f1['train_loss'], label='training loss')
plt.plot(bert_best_f1['val_loss'], label='validation loss')
plt.title('Train vs validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.ylim([0, 1]);
plt.tight_layout()
plt.show()
